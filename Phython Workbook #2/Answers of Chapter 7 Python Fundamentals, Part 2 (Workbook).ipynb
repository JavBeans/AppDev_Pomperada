# %%
#EXERCISE 1:

#Write a program to read through a file and print the contents of the file (line by line) all in upper case.

f = open('system.txt')
for line in f:
    print(line.upper(), end = '')
# Out:
# CEZAR RYAN POMPERADA
#
#
# X-DSPAM-CONFIDENCE: 0.8475
# X-DSPAM-CONFIDENCE: 0.9975
# X-DSPAM-CONFIDENCE: 0.6575

# %%
#EXERCISE 2:

#Write a program to read through a file and output the number of lines in a file.

f = open('system.txt')
text = f.read()
print(len(text))
# Out:
# 103

# %%
#CHALLENGE:

# Write a program to prompt for a file name, and then read through the file and look for lines of the form:

# When you encounter a line that starts with "X-DSPAM-Confidence:" pull apart the line to extract
# the floating-point number on the line. Count these lines and then compute the total of the spam
# confidence values from these lines. When you reach the end of the file, print out the average spam confidence.

f = open('system.txt')
number_DSPAM = 0.0
array_count  = 0
for line in f:
    line = line.strip()
    if line.startswith("X-DSPAM-Confidence:"):
        dspam_confidence = float(line.split(":")[1])
        number_DSPAM += dspam_confidence
        array_count += 1
average_dspam_confidence = number_DSPAM / array_count
print(f"Average spam confidence: {average_dspam_confidence:.2f}")
# Out:
# Average spam confidence: 0.83
