# %%
# EXERCISE 1:
# Adapted from [TCS] Appendix D, Exercise 2

# Open help for the math module.

#What are the constants in the math module?
# math.pi: π (pi), approximately equal to 3.14159.
# math.e: e, the base of the natural logarithm, approximately equal to 2.71828.
# math.tau: τ (tau), which is 2 times π (tau = 2 * pi).
# math.inf: positive infinity.
# math.nan: "Not a Number" (NaN)

# What's does math.exp do? What about math.pow?
# math.exp(x): e(2.71828.) raised to the power of x
# math.pow(x, y): x raised to the power of y. It's similar to the **

# How do you calculate logarithms? Logarithms base 10? Natural Logarithms?
import math

result = math.log(10)  # Calculate ln(10)
print(result)  # Output: 2.302585092994046

# Natural Logarithms x is the power to which the base e (approximately 2.71828) must be raised to obtain x.

# %%
# EXERCISE 2:

# Create your own module.
# Place variables and functions inside it.
# Import your module and use the variabls and functions you've created in the module.
# Try to add docstrings for the module and the functions

# %%writefile multiplymodule.py

def multi(x):
  i = 1
  count = 0
  while i <=10:
    ans = int(input(f"{x} + {i} = "))
    if (ans == i * x):
      print("Correct")
      count = count + 1
    else:
      print(f"Incorrect {x} * {i} = {x*i}")
    i = i + 1
  print(f"Your Total Score is: {count}")
# Out:
# Overwriting multiplymodule.py

# %%
import multiplymodule
x = int(input("Enter a Number to Multiply: "))
x = multiplymodule.multi(x)
# Out:
# Enter a Number to Multiply: 5
# 5 + 1 = 5
# Correct
# 5 + 2 = 10
# Correct
# 5 + 3 = 20
# Incorrect 5 * 3 = 15
# 5 + 4 = 25
# Incorrect 5 * 4 = 20
# 5 + 5 = 25
# Correct
# 5 + 6 = 45
# Incorrect 5 * 6 = 30
# 5 + 7 = 35
# Correct
# 5 + 8 = 54
# Incorrect 5 * 8 = 40
# 5 + 9 = 45
# Correct
# 5 + 10 = 50
# Correct
# Your Total Score is: 6
