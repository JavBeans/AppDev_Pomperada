# %%
# Exercise 1:

a = 2
b = 2.0
c = a

# print(a == c)  # both a and c have the same "VALUE", which is 2
# print(a is c)  # both a and c refer to the same "OBJECT" with value 2

# %%
#CHALLENGE 1:

# Write a program which repeatedly reads numbers until the user enters "done". Once "done" is entered, print out the total, count, and average of
#the numbers. If the user enters anything other than a number, detect their mistake using try and except and print an error message and skip to the next number.

# Enter a number: 4
# Enter a number: 5
# Enter a number: bad data
# Invalid input
# Enter a number: 7
# Enter a number: done
# 16 3 5.333333333333333

total = 0
count = 0

while True:
    try:
        user_input = input("Enter a number: ")

        if user_input == "done":
            break

        number = int(user_input)

        total += number
        count += 1

    except ValueError:
        print("Invalid input")
        continue

if count > 0:
    average = total / count
else:
    average = 0

print(total, count, average)
# Out:
# Enter a number: 4
# Enter a number: 5
# Enter a number: asd
# Invalid input
# Enter a number: 7
# Enter a number: done
# 16 3 5.333333333333333

# %%
#CHALLENGE 2:

#Write another program that prompts for a list of numbers as above and at the end
#prints out both the maximum and minimum of the numbers instead of the average.

numbers = []

while True:
    try:
        user_input = input("Enter a number: ")

        if user_input == "done":
            break

        number = int(user_input)
        numbers.append(number)

    except ValueError:
        print("Invalid input")
        continue

if numbers:
    maximum = max(numbers)
    minimum = min(numbers)

    print("Maximum:", maximum)
    print("Minimum:", minimum)
else:
    print("No numbers entered.")
# Out:
# Enter a number: 4
# Enter a number: 5
# Enter a number: as
# Invalid input
# Enter a number: 7
# Enter a number: done
# Maximum: 7.0
# Minimum: 4.0
