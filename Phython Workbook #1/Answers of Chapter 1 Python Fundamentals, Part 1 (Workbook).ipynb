# %%
#Exercise 1:

#Print('Hello world!')
print('Hello World!')
#"P" in Print must be small letter.

#print'Hello world!')
print('Hello world!')
#Missing open parenthesis  -> ( <-

#print('Hello world!)
print('Hello world!')
#Missing quotation mark  -> ' <-

#print('Hello world!'')
print('Hello world!')
#Too much quotation mark  -> ' <-
# Out:
# Hello World

# %%
#exercise 2:
x = 43
x = x + 1
print(x)
# Output = 44 because the value of x is 43 then you state that x + 1 so 43 + 1 = 44.

# %%
#exercise 3:
# x = 43
# x = X + 1
# print(x)
x = 43
x = x + 1
print(x)
#The "X" in x = X + 1 is Big letter so it must be the with your variable name.
